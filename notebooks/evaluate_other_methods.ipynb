# %%
import json
from pymodulon.io import load_json_model
from pymodulon import example_data
from pymodulon.core import IcaData

import networkx as nx
import os 
import sys
import numpy as np
import pandas as pd

sys.path.append("../src/modeval")
from modulescomparison import ModulesComparison
from modulecontainers import Modules

# %%
## Get the known RegulonDB network with modification described in inspect_input_elements.ipynb
known_trn = pd.read_csv("../data/Regulatory/QCd_Network.csv", index_col=0)
known_trn.head()
# Out:
#           regulatorId regulatorName RegulatorGeneName       regulatedId  \
# 313  RDBECOLIPDC00358          DsrA              dsrA  RDBECOLIGNC00450
# 315  RDBECOLIPDC00358          DsrA              dsrA  RDBECOLIGNC00539
# 316  RDBECOLIPDC00358          DsrA              dsrA  RDBECOLIGNC00804
# 317  RDBECOLIPDC00358          DsrA              dsrA  RDBECOLIGNC00805
# 318  RDBECOLIPDC00358          DsrA              dsrA  RDBECOLIGNC00806
#
#     regulatedName function confidenceLevel
# 313           hns        -              S
# 315           lrp        -              S
# 316          rbsA        -              S
# 317          rbsB        -              S
# 318          rbsC        -              S

# %%
## Load the annotation E Coli 
annotation = pd.read_csv("../data/Annotation/gene_info.csv")
annotation.head()
# Out:
#   locus_tag gene_name  old_locus_tag  start   end strand  \
# 0     b0001      thrL            NaN    190   255      +
# 1     b0002      thrA            NaN    337  2799      +
# 2     b0003      thrB            NaN   2801  3733      +
# 3     b0004      thrC            NaN   3734  5020      +
# 4     b0005      yaaX            NaN   5234  5530      +
#
#                                         gene_product  \
# 0                          thr operon leader peptide
# 1  fused aspartate kinase/homoserine dehydrogenase 1
# 2                                  homoserine kinase
# 3                                 threonine synthase
# 4             DUF2502 domain-containing protein YaaX
#
#                                    COG uniprot
# 0                    No COG annotation  P0AD86
# 1  Amino acid transport and metabolism  P00561
# 2  Nucleotide transport and metabolism  P00547
# 3  Amino acid transport and metabolism  P00934
# 4                     Function unknown  P75616

# %%
# Define the set of all known genes (E)
all_genes = annotation.locus_tag.values 

# Define a set of all known regulators
known_regulators = known_trn['RegulatorGeneName'].unique()

# Map gene names to locus tags for comparable output with GENIE3 ouput
annotation_map = annotation[annotation.gene_name.notna()].set_index("gene_name")["locus_tag"].to_dict()
known_trn['targets_tags'] = known_trn["regulatedName"].map(annotation_map)

# %%
# Iterate over regulators and gene targets to load a graph from edges
known_ecoli_trn = nx.Graph() 
for i in known_trn[['RegulatorGeneName', 'targets_tags']].itertuples():
    known_ecoli_trn.add_edges_from([tuple([i[1], i[2]])]) 
    
edges_ecoli_trn = known_ecoli_trn.edges

# Find the neighbors of the regulators to define gene targets 
known_modules = []
for reg in known_regulators:
    known_modules.append(list(known_ecoli_trn.neighbors(reg)))

# %%
example_data.A
# Out:
#                    control__wt_glc__1  control__wt_glc__2  fur__wt_dpd__1  \
# AllR/AraC/FucR               0.378690           -0.378690        2.457678
# ArcA-1                      -0.440210            0.440210       -5.367360
# ArcA-2                       0.762258           -0.762258        2.619623
# ArgR                        -0.289630            0.289630      -10.085719
# AtoC                         0.250770           -0.250770        1.844767
# ...                               ...                 ...             ...
# uncharacterized-4            0.597480           -0.597480       -8.707623
# uncharacterized-5           -0.497327            0.497327      -16.669187
# uncharacterized-6            0.581999           -0.581999       -7.842130
# ydcI-KO                      0.269057           -0.269057       -0.254271
# yheO-KO                     -0.056872            0.056872        1.180566
#
#                    fur__wt_dpd__2  fur__wt_fe__1  fur__wt_fe__2  \
# AllR/AraC/FucR           2.248678      -0.327344      -0.259164
# ArcA-1                  -5.684301       0.131174       0.348843
# ArcA-2                   2.900696       3.120724       2.743634
# ArgR                   -13.187916       2.371129       1.861918
# AtoC                     2.055052       0.299345       0.425502
# ...                           ...            ...            ...
# uncharacterized-4       -7.812802       0.323410       1.331085
# uncharacterized-5      -17.120903       0.228383       0.056799
# uncharacterized-6       -9.298792       2.352067       2.750720
# ydcI-KO                  0.184537       0.651527       0.691914
# yheO-KO                  1.180204       1.065531       0.511764
#
#                    fur__delfur_dpd__1  fur__delfur_dpd__2  fur__delfur_fe2__1  \
# AllR/AraC/FucR               1.777251            2.690655            0.656937
# ArcA-1                      -4.436389           -4.770469           -1.799113
# ArcA-2                       1.989803            1.555835            1.782500
# ArgR                        -8.708701           -7.881588           -1.237027
# AtoC                         1.801217            1.790987            0.921254
# ...                               ...                 ...                 ...
# uncharacterized-4           -7.711778           -6.652678            1.087082
# uncharacterized-5          -14.972028          -13.434012           -3.997564
# uncharacterized-6           -6.310719           -6.370995            2.112088
# ydcI-KO                      0.016636           -0.465781            1.212097
# yheO-KO                      0.779575            0.600318            0.847090
#
#                    fur__delfur_fe2__2  ...  efeU__menFentC_ale29__1  \
# AllR/AraC/FucR               0.319583  ...                 1.041336
# ArcA-1                      -1.474222  ...                -6.471714
# ArcA-2                       1.530811  ...                 2.789653
# ArgR                        -1.235604  ...               -11.263744
# AtoC                         1.410026  ...                 3.821909
# ...                               ...  ...                      ...
# uncharacterized-4            1.005071  ...                -3.803681
# uncharacterized-5           -4.300753  ...               -27.990992
# uncharacterized-6            1.685886  ...                 0.866587
# ydcI-KO                      1.122801  ...                -3.646464
# yheO-KO                      1.029993  ...                 0.495970
#
#                    efeU__menFentC_ale29__2  efeU__menFentC_ale30__1  \
# AllR/AraC/FucR                    2.203940                 3.698292
# ArcA-1                           -6.549861                -3.109145
# ArcA-2                            3.959650                 1.585147
# ArgR                            -10.366813                -0.289217
# AtoC                              3.306573                 2.652394
# ...                                    ...                      ...
# uncharacterized-4                -3.201872                -3.475330
# uncharacterized-5               -28.543522                -3.447801
# uncharacterized-6                 1.694439                 0.436875
# ydcI-KO                          -3.606055                -0.665810
# yheO-KO                           0.077482                -1.265258
#
#                    efeU__menFentC_ale30__2  efeU__menFentCubiC_ale36__1  \
# AllR/AraC/FucR                    0.856998                     1.557323
# ArcA-1                           -2.716183                    -2.531192
# ArcA-2                            0.811182                     0.300414
# ArgR                              0.389228                    -5.142768
# AtoC                              1.910173                     0.927772
# ...                                    ...                          ...
# uncharacterized-4                -3.297351                    -5.398908
# uncharacterized-5                -1.648500                    -5.807751
# uncharacterized-6                 0.705672                     3.500528
# ydcI-KO                          -0.830586                    -1.044574
# yheO-KO                          -1.595661                    -1.686416
#
#                    efeU__menFentCubiC_ale36__2  efeU__menFentCubiC_ale37__1  \
# AllR/AraC/FucR                        0.337806                     0.943742
# ArcA-1                               -1.461022                    -0.408849
# ArcA-2                                2.537535                     1.061408
# ArgR                                 -5.014526                    -3.648777
# AtoC                                  1.327549                     1.846321
# ...                                        ...                          ...
# uncharacterized-4                    -5.611798                    -5.662947
# uncharacterized-5                    -6.571386                    -8.404540
# uncharacterized-6                     3.741011                     5.988410
# ydcI-KO                               0.119876                    -0.045670
# yheO-KO                              -0.456617                    -2.134343
#
#                    efeU__menFentCubiC_ale37__2  efeU__menFentCubiC_ale38__1  \
# AllR/AraC/FucR                        1.736640                     0.499461
# ArcA-1                               -0.210397                    -5.700321
# ArcA-2                                2.634524                     0.125513
# ArgR                                 -4.125952                    -4.286326
# AtoC                                  0.909667                     2.064662
# ...                                        ...                          ...
# uncharacterized-4                    -4.948391                    -4.582840
# uncharacterized-5                    -8.295630                    -6.039384
# uncharacterized-6                     5.595631                     7.619875
# ydcI-KO                              -0.826608                    -1.393160
# yheO-KO                              -1.465515                    -0.418143
#
#                    efeU__menFentCubiC_ale38__2
# AllR/AraC/FucR                        1.581476
# ArcA-1                               -6.237836
# ArcA-2                                1.178747
# ArgR                                 -5.475940
# AtoC                                  2.371405
# ...                                        ...
# uncharacterized-4                    -5.443213
# uncharacterized-5                    -7.430400
# uncharacterized-6                     6.295446
# ydcI-KO                              -1.587978
# yheO-KO                              -1.416905
#
# [92 rows x 278 columns]

# %%
example_trn = example_data.trn
example_sample = example_data.sample_table
example_gene = example_data.gene_table
example_A = example_data.A
example_M = example_data.M
example_X = example_data.X

# %%
example_M.columns = list(range(len(example_M.columns)))
example_A.index = list(range(len(example_A.index)))
example_A
# Out:
#     control__wt_glc__1  control__wt_glc__2  fur__wt_dpd__1  fur__wt_dpd__2  \
# 0             0.378690           -0.378690        2.457678        2.248678
# 1            -0.440210            0.440210       -5.367360       -5.684301
# 2             0.762258           -0.762258        2.619623        2.900696
# 3            -0.289630            0.289630      -10.085719      -13.187916
# 4             0.250770           -0.250770        1.844767        2.055052
# ..                 ...                 ...             ...             ...
# 87            0.597480           -0.597480       -8.707623       -7.812802
# 88           -0.497327            0.497327      -16.669187      -17.120903
# 89            0.581999           -0.581999       -7.842130       -9.298792
# 90            0.269057           -0.269057       -0.254271        0.184537
# 91           -0.056872            0.056872        1.180566        1.180204
#
#     fur__wt_fe__1  fur__wt_fe__2  fur__delfur_dpd__1  fur__delfur_dpd__2  \
# 0       -0.327344      -0.259164            1.777251            2.690655
# 1        0.131174       0.348843           -4.436389           -4.770469
# 2        3.120724       2.743634            1.989803            1.555835
# 3        2.371129       1.861918           -8.708701           -7.881588
# 4        0.299345       0.425502            1.801217            1.790987
# ..            ...            ...                 ...                 ...
# 87       0.323410       1.331085           -7.711778           -6.652678
# 88       0.228383       0.056799          -14.972028          -13.434012
# 89       2.352067       2.750720           -6.310719           -6.370995
# 90       0.651527       0.691914            0.016636           -0.465781
# 91       1.065531       0.511764            0.779575            0.600318
#
#     fur__delfur_fe2__1  fur__delfur_fe2__2  ...  efeU__menFentC_ale29__1  \
# 0             0.656937            0.319583  ...                 1.041336
# 1            -1.799113           -1.474222  ...                -6.471714
# 2             1.782500            1.530811  ...                 2.789653
# 3            -1.237027           -1.235604  ...               -11.263744
# 4             0.921254            1.410026  ...                 3.821909
# ..                 ...                 ...  ...                      ...
# 87            1.087082            1.005071  ...                -3.803681
# 88           -3.997564           -4.300753  ...               -27.990992
# 89            2.112088            1.685886  ...                 0.866587
# 90            1.212097            1.122801  ...                -3.646464
# 91            0.847090            1.029993  ...                 0.495970
#
#     efeU__menFentC_ale29__2  efeU__menFentC_ale30__1  efeU__menFentC_ale30__2  \
# 0                  2.203940                 3.698292                 0.856998
# 1                 -6.549861                -3.109145                -2.716183
# 2                  3.959650                 1.585147                 0.811182
# 3                -10.366813                -0.289217                 0.389228
# 4                  3.306573                 2.652394                 1.910173
# ..                      ...                      ...                      ...
# 87                -3.201872                -3.475330                -3.297351
# 88               -28.543522                -3.447801                -1.648500
# 89                 1.694439                 0.436875                 0.705672
# 90                -3.606055                -0.665810                -0.830586
# 91                 0.077482                -1.265258                -1.595661
#
#     efeU__menFentCubiC_ale36__1  efeU__menFentCubiC_ale36__2  \
# 0                      1.557323                     0.337806
# 1                     -2.531192                    -1.461022
# 2                      0.300414                     2.537535
# 3                     -5.142768                    -5.014526
# 4                      0.927772                     1.327549
# ..                          ...                          ...
# 87                    -5.398908                    -5.611798
# 88                    -5.807751                    -6.571386
# 89                     3.500528                     3.741011
# 90                    -1.044574                     0.119876
# 91                    -1.686416                    -0.456617
#
#     efeU__menFentCubiC_ale37__1  efeU__menFentCubiC_ale37__2  \
# 0                      0.943742                     1.736640
# 1                     -0.408849                    -0.210397
# 2                      1.061408                     2.634524
# 3                     -3.648777                    -4.125952
# 4                      1.846321                     0.909667
# ..                          ...                          ...
# 87                    -5.662947                    -4.948391
# 88                    -8.404540                    -8.295630
# 89                     5.988410                     5.595631
# 90                    -0.045670                    -0.826608
# 91                    -2.134343                    -1.465515
#
#     efeU__menFentCubiC_ale38__1  efeU__menFentCubiC_ale38__2
# 0                      0.499461                     1.581476
# 1                     -5.700321                    -6.237836
# 2                      0.125513                     1.178747
# 3                     -4.286326                    -5.475940
# 4                      2.064662                     2.371405
# ..                          ...                          ...
# 87                    -4.582840                    -5.443213
# 88                    -6.039384                    -7.430400
# 89                     7.619875                     6.295446
# 90                    -1.393160                    -1.587978
# 91                    -0.418143                    -1.416905
#
# [92 rows x 278 columns]

# %%
ica_data = IcaData(example_M,example_A,example_X)
ica_data.trn = example_trn
ica_data.gene_table = example_gene
ica_data.sample_table = example_sample

# %%
modulons = IcaData(ica_data.M,
                   ica_data.A,
                   ica_data.X,
                   gene_table=ica_data.gene_table,
                   trn=ica_data.trn,
                   threshold_method='dagostino',
                   optimize_cutoff=True)
# Out:
# WARNING:root:Optimizing iModulon thresholds, may take 2-3 minutes...

# %%
modulons.view_imodulon(0)
# Out:
#        gene_weight    start      end strand gene_name  length  \
# b0061     0.159019    65854    66550      -      araD     696
# b0062     0.164871    66834    68337      -      araA    1503
# b0063     0.176550    68347    70048      -      araB    1701
# b0505     0.161867   532450   532933      +      allA     483
# b0507     0.265127   533915   535697      +       gcl    1782
# b0508     0.316052   535709   536486      +       hyi     777
# b0509     0.321224   536585   537464      +      glxR     879
# b0511     0.150539   537632   539087      +      ybbW    1455
# b0512     0.248491   539146   540508      +      allB    1362
# b1900     0.091065  1983554  1985069      -      araG    1515
# b1901     0.135788  1985138  1986128      -      araF     990
# b2799     0.090071  2931864  2933013      -      fucO    1149
# b2800     0.087933  2933040  2933688      -      fucA     648
# b2801     0.107154  2934234  2935551      +      fucP    1317
# b2802     0.100580  2935583  2937359      +      fucI    1776
# b2803     0.087447  2937467  2938886      +      fucK    1419
# b2841     0.097535  2980763  2982182      -      araE    1419
# b4460     0.087230  1982553  1983540      -      araH     987
#
#                                  operon  \
# b0061                            araBAD
# b0062                            araBAD
# b0063                            araBAD
# b0505                              allA
# b0507  gcl-hyi-glxR-ybbW-allB-ybbY-glxK
# b0508  gcl-hyi-glxR-ybbW-allB-ybbY-glxK
# b0509  gcl-hyi-glxR-ybbW-allB-ybbY-glxK
# b0511  gcl-hyi-glxR-ybbW-allB-ybbY-glxK
# b0512  gcl-hyi-glxR-ybbW-allB-ybbY-glxK
# b1900                            araFGH
# b1901                            araFGH
# b2799                             fucAO
# b2800                             fucAO
# b2801                          fucPIKUR
# b2802                          fucPIKUR
# b2803                          fucPIKUR
# b2841                         araE-ygeA
# b4460                            araFGH
#
#                                           COG    accession  \
# b0061   Carbohydrate transport and metabolism  NC_000913.3
# b0062   Carbohydrate transport and metabolism  NC_000913.3
# b0063   Carbohydrate transport and metabolism  NC_000913.3
# b0505     Nucleotide transport and metabolism  NC_000913.3
# b0507                        Function unknown  NC_000913.3
# b0508   Carbohydrate transport and metabolism  NC_000913.3
# b0509          Lipid transport and metabolism  NC_000913.3
# b0511     Nucleotide transport and metabolism  NC_000913.3
# b0512     Nucleotide transport and metabolism  NC_000913.3
# b1900  Inorganic ion transport and metabolism  NC_000913.3
# b1901   Carbohydrate transport and metabolism  NC_000913.3
# b2799        Energy production and conversion  NC_000913.3
# b2800   Carbohydrate transport and metabolism  NC_000913.3
# b2801   Carbohydrate transport and metabolism  NC_000913.3
# b2802   Carbohydrate transport and metabolism  NC_000913.3
# b2803   Carbohydrate transport and metabolism  NC_000913.3
# b2841   Carbohydrate transport and metabolism  NC_000913.3
# b4460   Carbohydrate transport and metabolism  NC_000913.3
#
#                          regulator
# b0061                araC,crp,rpoD
# b0062                araC,crp,rpoD
# b0063                araC,crp,rpoD
# b0505                         allR
# b0507                    allR,rpoD
# b0508                    allR,rpoD
# b0509                    allR,rpoD
# b0511               allR,rpoD,yeiE
# b0512                    allR,rpoD
# b1900       araC,crp,nac,rpoD,rpoS
# b1901  araC,crp,nac,rpoD,rpoS,yieP
# b2799                crp,fucR,rpoD
# b2800                crp,fucR,rpoD
# b2801                crp,fucR,rpoD
# b2802                crp,fucR,rpoD
# b2803                crp,fucR,rpoD
# b2841                araC,crp,rpoD
# b4460       araC,crp,nac,rpoD,rpoS

# %%
locus_tags = []
for k in modulons.imodulon_names:
    locus_tag = list(modulons.view_imodulon(k).index)
    locus_tags.append(locus_tag)

# %%
locus_tags
# Out:
# [['b0061',
#   'b0062',
#   'b0063',
#   'b0505',
#   'b0507',
#   'b0508',
#   'b0509',
#   'b0511',
#   'b0512',
#   'b1900',
#   'b1901',
#   'b2799',
#   'b2800',
#   'b2801',
#   'b2802',
#   'b2803',
#   'b2841',
#   'b4460'],
#  ['b0042',
#   'b0113',
#   'b0124',
#   'b0330',
#   'b0346',
#   'b0429',
#   'b0430',
#   'b0431',
#   'b0432',
#   'b0458',
#   'b0557',
#   'b0621',
#   'b0721',
#   'b0722',
#   'b0723',
#   'b0724',
#   'b0836',
#   'b0848',
#   'b1020',
#   'b1189',
#   'b1190',
#   'b1297',
#   'b1298',
#   'b1332',
#   'b1422',
#   'b1518',
#   'b1607',
#   'b1748',
#   'b1777',
#   'b1778',
#   'b2181',
#   'b2210',
#   'b2241',
#   'b2242',
#   'b2518',
#   'b2582',
#   'b2587',
#   'b2847',
#   'b2848',
#   'b2980',
#   'b3351',
#   'b3426',
#   'b3452',
#   'b3453',
#   'b3528',
#   'b3603',
#   'b3820',
#   'b3894',
#   'b3962',
#   'b4705'],
#  ['b0034',
#   'b0429',
#   'b0430',
#   'b0431',
#   'b0432',
#   'b0733',
#   'b0734',
#   'b0763',
#   'b0972',
#   'b0973',
#   'b0974',
#   'b0975',
#   'b0976',
#   'b0977',
#   'b0978',
#   'b0979',
#   'b1109',
#   'b1256',
#   'b2579',
#   'b2720',
#   'b2725',
#   'b2998',
#   'b4070',
#   'b4071',
#   'b4073'],
#  ['b0032',
#   'b0272',
#   'b0273',
#   'b0709',
#   'b0860',
#   'b2818',
#   'b3172',
#   'b3359',
#   'b3957',
#   'b3958',
#   'b3959',
#   'b3960',
#   'b4254'],
#  ['b1796', 'b1800', 'b2221', 'b2222', 'b2223', 'b2224'],
#  ['b0061',
#   'b0062',
#   'b0063',
#   'b0344',
#   'b0349',
#   'b0350',
#   'b0351',
#   'b0352',
#   'b0954',
#   'b2323',
#   'b2599',
#   'b2899',
#   'b3903',
#   'b4252',
#   'b4253',
#   'b4350',
#   'b4363'],
#  ['b0365',
#   'b0366',
#   'b0367',
#   'b0368',
#   'b0934',
#   'b0935',
#   'b0936',
#   'b0937',
#   'b3917',
#   'b4326'],
#  ['b0162',
#   'b1800',
#   'b2787',
#   'b2788',
#   'b2789',
#   'b3124',
#   'b3125',
#   'b3126',
#   'b3127',
#   'b3128'],
#  ['b0792', 'b0793', 'b0794', 'b0795', 'b0796'],
#  ['b0123', 'b0484', 'b0570', 'b0571', 'b0572', 'b0573', 'b0574', 'b0575'],
#  ['b0287',
#   'b0460',
#   'b0461',
#   'b0837',
#   'b0970',
#   'b1113',
#   'b1535',
#   'b1597',
#   'b1600',
#   'b1829',
#   'b1843',
#   'b1846',
#   'b1902',
#   'b2597',
#   'b3088',
#   'b4188',
#   'b4484'],
#  ['b0080',
#   'b1241',
#   'b1702',
#   'b1780',
#   'b2165',
#   'b2166',
#   'b2167',
#   'b2168',
#   'b2169',
#   'b2925',
#   'b2926',
#   'b2927',
#   'b3365',
#   'b3612',
#   'b4232'],
#  ['b0080',
#   'b0268',
#   'b0269',
#   'b0306',
#   'b0553_1',
#   'b0598',
#   'b0651',
#   'b0721',
#   'b0729',
#   'b0791',
#   'b0836',
#   'b0899',
#   'b1008',
#   'b1020',
#   'b1415',
#   'b1423',
#   'b1440',
#   'b1441',
#   'b1442',
#   'b1617',
#   'b1776',
#   'b1853',
#   'b1895',
#   'b1976',
#   'b2151',
#   'b2166',
#   'b2175',
#   'b2272',
#   'b2535',
#   'b2844',
#   'b2869',
#   'b2957',
#   'b3020',
#   'b3081',
#   'b3092',
#   'b3132',
#   'b3133',
#   'b3134',
#   'b3224',
#   'b3225',
#   'b3570',
#   'b3588',
#   'b3599',
#   'b3600',
#   'b3601',
#   'b3708',
#   'b3709',
#   'b3748',
#   'b3934',
#   'b4055',
#   'b4067',
#   'b4068',
#   'b4069',
#   'b4090',
#   'b4123',
#   'b4128',
#   'b4139',
#   'b4216',
#   'b4240',
#   'b4487'],
#  ['b0553_1',
#   'b0723',
#   'b1101',
#   'b1143',
#   'b1145',
#   'b1205',
#   'b1415',
#   'b1426',
#   'b1596',
#   'b1817',
#   'b1818',
#   'b1819',
#   'b2091',
#   'b2092_1',
#   'b2092_2',
#   'b2093',
#   'b2094',
#   'b2095',
#   'b2096',
#   'b2143',
#   'b2148',
#   'b2149',
#   'b2150',
#   'b2151',
#   'b2239',
#   'b2240',
#   'b2597',
#   'b2796',
#   'b3001',
#   'b3358',
#   'b3403',
#   'b3476',
#   'b3599',
#   'b3600',
#   'b3601',
#   'b3774',
#   'b4021',
#   'b4267',
#   'b4357',
#   'b4498_1'],
#  ['b3875',
#   'b3876',
#   'b3877',
#   'b3878',
#   'b3879',
#   'b3880',
#   'b3881',
#   'b3882',
#   'b3883',
#   'b3884'],
#  ['b0828',
#   'b0829',
#   'b1287',
#   'b1729',
#   'b1920',
#   'b1987',
#   'b2012',
#   'b2013',
#   'b2414',
#   'b2421',
#   'b2422',
#   'b2423',
#   'b2424',
#   'b2425',
#   'b2750',
#   'b2751',
#   'b2752',
#   'b2762',
#   'b2763',
#   'b2764',
#   'b3917'],
#  ['b1101',
#   'b1198',
#   'b1199',
#   'b1200',
#   'b1817',
#   'b1818',
#   'b1819',
#   'b2416',
#   'b2943',
#   'b3599',
#   'b3600'],
#  ['b1223',
#   'b1466',
#   'b1467',
#   'b1468',
#   'b1469',
#   'b1499',
#   'b1501',
#   'b1597',
#   'b2082',
#   'b2085',
#   'b2106',
#   'b2367',
#   'b2368',
#   'b2371',
#   'b2372',
#   'b2373',
#   'b2374',
#   'b2375',
#   'b2376',
#   'b4354'],
#  ['b0268',
#   'b0269',
#   'b1521',
#   'b2172',
#   'b2799',
#   'b2800',
#   'b2801',
#   'b2802',
#   'b2803',
#   'b2804',
#   'b3011',
#   'b3091',
#   'b3092',
#   'b3093',
#   'b4025'],
#  ['b0221',
#   'b0443',
#   'b0557',
#   'b0954',
#   'b1187',
#   'b1949',
#   'b2341',
#   'b2342',
#   'b3081',
#   'b3845',
#   'b3846',
#   'b3963',
#   'b4015'],
#  ['b0595',
#   'b1018',
#   'b1019',
#   'b4039',
#   'b4287',
#   'b4288',
#   'b4289',
#   'b4290',
#   'b4291',
#   'b4490_2'],
#  ['b1044',
#   'b1070',
#   'b1071',
#   'b1072',
#   'b1073',
#   'b1074',
#   'b1075',
#   'b1076',
#   'b1077',
#   'b1078',
#   'b1079',
#   'b1080',
#   'b1081',
#   'b1082',
#   'b1083',
#   'b1878',
#   'b1879',
#   'b1880',
#   'b1891',
#   'b1892',
#   'b1904',
#   'b1921',
#   'b1922',
#   'b1924',
#   'b1925',
#   'b1926',
#   'b1937',
#   'b1938',
#   'b1939',
#   'b1940',
#   'b1941',
#   'b1942',
#   'b1943',
#   'b1944',
#   'b1945',
#   'b1946',
#   'b1947',
#   'b1948',
#   'b1949',
#   'b1950',
#   'b3525'],
#  ['b0763',
#   'b0764',
#   'b1070',
#   'b1071',
#   'b1082',
#   'b1083',
#   'b1194',
#   'b1421',
#   'b1566',
#   'b1742',
#   'b1760',
#   'b1881',
#   'b1882',
#   'b1883',
#   'b1884',
#   'b1885',
#   'b1886',
#   'b1887',
#   'b1888',
#   'b1889',
#   'b1890',
#   'b1923',
#   'b1924',
#   'b1925',
#   'b1926',
#   'b3072',
#   'b3525',
#   'b3666',
#   'b4110',
#   'b4355'],
#  ['b0621',
#   'b0715',
#   'b0836',
#   'b0894',
#   'b0904',
#   'b0919',
#   'b1223',
#   'b1224',
#   'b1256',
#   'b1474',
#   'b1541',
#   'b1587',
#   'b1593',
#   'b1750',
#   'b1751',
#   'b1757',
#   'b1785',
#   'b1906',
#   'b2207',
#   'b2208',
#   'b2298',
#   'b2531',
#   'b2579',
#   'b2727',
#   'b2997',
#   'b3060',
#   'b3158',
#   'b3159',
#   'b3211',
#   'b3365',
#   'b3366',
#   'b3408',
#   'b3409',
#   'b3476',
#   'b3477',
#   'b4139',
#   'b4154',
#   'b4238',
#   'b4380',
#   'b4582_1'],
#  ['b0151',
#   'b0152',
#   'b0153',
#   'b0583',
#   'b0584',
#   'b0585',
#   'b0586',
#   'b0587',
#   'b0588',
#   'b0589',
#   'b0590',
#   'b0591',
#   'b0592',
#   'b0593',
#   'b0594',
#   'b0595',
#   'b0596',
#   'b0597',
#   'b0803',
#   'b0804',
#   'b0805',
#   'b1102',
#   'b1452',
#   'b1494',
#   'b1495',
#   'b1496',
#   'b1656',
#   'b1679',
#   'b1680',
#   'b1681',
#   'b1682',
#   'b1683',
#   'b1684',
#   'b1705',
#   'b2155',
#   'b2673',
#   'b2674',
#   'b2675',
#   'b2676',
#   'b3070',
#   'b3336',
#   'b4291',
#   'b4292',
#   'b4293',
#   'b4511',
#   'b4567',
#   'b4582_1',
#   'b4640_1'],
#  ['b0150',
#   'b0151',
#   'b0152',
#   'b0468',
#   'b0585',
#   'b0588',
#   'b0589',
#   'b0590',
#   'b0591',
#   'b0592',
#   'b1252',
#   'b1452',
#   'b1673',
#   'b1674',
#   'b1905',
#   'b2146',
#   'b2211',
#   'b2673',
#   'b3005',
#   'b3006',
#   'b3337',
#   'b3408',
#   'b3409',
#   'b3515',
#   'b4293',
#   'b4367',
#   'b4490_2'],
#  ['b0485',
#   'b1492',
#   'b1493',
#   'b3491',
#   'b3506',
#   'b3507',
#   'b3508',
#   'b3509',
#   'b3510',
#   'b3511',
#   'b3512',
#   'b3513',
#   'b3514',
#   'b3515',
#   'b3517',
#   'b4187',
#   'b4377'],
#  ['b0485', 'b0486', 'b3506', 'b3507', 'b3513', 'b3514', 'b3515', 'b3516'],
#  ['b2902', 'b2903', 'b2904', 'b2905'],
#  ['b2975', 'b2976', 'b2977', 'b2979', 'b4467', 'b4468'],
#  ['b2239',
#   'b2240',
#   'b2241',
#   'b2242',
#   'b2243',
#   'b3426',
#   'b3925',
#   'b3926',
#   'b3927'],
#  ['b0112',
#   'b1850',
#   'b1851',
#   'b1907',
#   'b3161',
#   'b3415',
#   'b3437',
#   'b3892',
#   'b3893',
#   'b4264',
#   'b4265',
#   'b4266',
#   'b4267',
#   'b4268',
#   'b4476'],
#  ['b2019',
#   'b2020',
#   'b2021',
#   'b2022',
#   'b2023',
#   'b2024',
#   'b2025',
#   'b2026',
#   'b4388'],
#  ['b0003',
#   'b0004',
#   'b0005',
#   'b0071',
#   'b0072',
#   'b0073',
#   'b0074',
#   'b3769',
#   'b3770',
#   'b3771',
#   'b3772',
#   'b3774',
#   'b4488_1',
#   'b4488_2'],
#  ['b0077',
#   'b0078',
#   'b0381',
#   'b1189',
#   'b1190',
#   'b1243',
#   'b1244',
#   'b1245',
#   'b1246',
#   'b1247',
#   'b1534',
#   'b1605',
#   'b1634',
#   'b1798',
#   'b1814',
#   'b2209',
#   'b2669',
#   'b2670',
#   'b2796',
#   'b2797',
#   'b2845',
#   'b3089',
#   'b3454',
#   'b3455',
#   'b3456',
#   'b3457',
#   'b3458',
#   'b3460',
#   'b3496',
#   'b3523',
#   'b3616',
#   'b3617',
#   'b3673',
#   'b3774',
#   'b3829',
#   'b4045',
#   'b4129'],
#  ['b3416',
#   'b3417',
#   'b3418',
#   'b4032',
#   'b4033',
#   'b4034',
#   'b4035',
#   'b4036',
#   'b4037'],
#  ['b0197',
#   'b0198',
#   'b0199',
#   'b0260',
#   'b0261',
#   'b0599',
#   'b0600',
#   'b2942',
#   'b3008',
#   'b3828',
#   'b3829',
#   'b3937',
#   'b3938',
#   'b3939',
#   'b3940',
#   'b3941',
#   'b4013'],
#  ['b0336',
#   'b0338',
#   'b0644',
#   'b0929',
#   'b1339',
#   'b1384',
#   'b1440',
#   'b1441',
#   'b1442',
#   'b1443',
#   'b1444',
#   'b1932',
#   'b1981',
#   'b1988',
#   'b2661',
#   'b2662',
#   'b2663',
#   'b2664',
#   'b2883',
#   'b2913',
#   'b3043',
#   'b3212',
#   'b3213',
#   'b3225',
#   'b3324',
#   'b3326',
#   'b3446',
#   'b3523',
#   'b3540',
#   'b3541',
#   'b3543',
#   'b3544',
#   'b3712',
#   'b3744',
#   'b4208',
#   'b4464',
#   'b4646_2'],
#  ['b0112',
#   'b0677',
#   'b0678',
#   'b0679',
#   'b0681',
#   'b1497',
#   'b1498',
#   'b1634',
#   'b1734',
#   'b1735',
#   'b1737',
#   'b1738',
#   'b1907',
#   'b2943',
#   'b3161',
#   'b3729',
#   'b3730'],
#  ['b0895',
#   'b0896',
#   'b1223',
#   'b1224',
#   'b1225',
#   'b1226',
#   'b1227',
#   'b2111',
#   'b2195',
#   'b2196',
#   'b2197',
#   'b2199',
#   'b2201',
#   'b2202',
#   'b2203',
#   'b2204',
#   'b2205',
#   'b2206',
#   'b2207',
#   'b2208',
#   'b3365',
#   'b3366',
#   'b3367',
#   'b3476',
#   'b4070',
#   'b4071',
#   'b4072',
#   'b4073',
#   'b4506'],
#  ['b0208', 'b3476', 'b3477', 'b3478', 'b3479', 'b3480'],
#  ['b0331',
#   'b0450',
#   'b0451',
#   'b0655',
#   'b0674',
#   'b0854',
#   'b1006',
#   'b1007',
#   'b1008',
#   'b1009',
#   'b1010',
#   'b1011',
#   'b1012',
#   'b1218',
#   'b1483',
#   'b1484',
#   'b1485',
#   'b1486',
#   'b1487',
#   'b1488',
#   'b1596',
#   'b1597',
#   'b1744',
#   'b1745',
#   'b1746',
#   'b1747',
#   'b1748',
#   'b1781',
#   'b1783',
#   'b1784',
#   'b1797',
#   'b1826',
#   'b1932',
#   'b1987',
#   'b2106',
#   'b2306',
#   'b2310',
#   'b2659',
#   'b2660',
#   'b2663',
#   'b2726',
#   'b2870',
#   'b2875',
#   'b2876',
#   'b3073',
#   'b3268_2',
#   'b3269',
#   'b3270',
#   'b3271',
#   'b3744',
#   'b3868',
#   'b3869',
#   'b3870',
#   'b4002',
#   'b4079',
#   'b4242'],
#  ['b0605', 'b0606', 'b0812', 'b0849', 'b2582', 'b3518', 'b3942', 'b3961'],
#  ['b0331', 'b0333', 'b0334', 'b0335', 'b2416', 'b2943'],
#  ['b0522',
#   'b0523',
#   'b1131',
#   'b1623',
#   'b1660',
#   'b1849',
#   'b2312',
#   'b2313',
#   'b2476',
#   'b2499',
#   'b2500',
#   'b2557',
#   'b3654',
#   'b4005',
#   'b4006',
#   'b4064'],
#  ['b0032',
#   'b0033',
#   'b0336',
#   'b0337',
#   'b0945',
#   'b2497',
#   'b2498',
#   'b4243',
#   'b4244',
#   'b4245'],
#  ['b1296', 'b1297', 'b1298', 'b1299', 'b1300', 'b1301', 'b1302'],
#  ['b0114', 'b0115', 'b1380', 'b2210', 'b2296', 'b3547', 'b4353', 'b4354'],
#  ['b3666', 'b3748', 'b3749', 'b3750', 'b3751', 'b3752'],
#  ['b0439',
#   'b1951',
#   'b2028',
#   'b2044',
#   'b2045',
#   'b2046',
#   'b2047',
#   'b2048',
#   'b2049',
#   'b2050',
#   'b2051',
#   'b2052',
#   'b2053',
#   'b2054',
#   'b2055',
#   'b2056',
#   'b2057',
#   'b2058',
#   'b2059',
#   'b2060',
#   'b2061',
#   'b2062',
#   'b3357',
#   'b3563',
#   'b4026',
#   'b4027',
#   'b4028',
#   'b4029'],
#  ['b0014',
#   'b0015',
#   'b0473',
#   'b1321',
#   'b1322',
#   'b2592',
#   'b3686',
#   'b3687',
#   'b3931',
#   'b3932',
#   'b4140',
#   'b4142',
#   'b4143'],
#  ['b0304',
#   'b0325',
#   'b0329',
#   'b0384',
#   'b0453',
#   'b0456',
#   'b0581',
#   'b0643',
#   'b0707',
#   'b0753',
#   'b0788',
#   'b0789',
#   'b0790',
#   'b0808',
#   'b0837',
#   'b0871',
#   'b0897',
#   'b0906',
#   'b1003',
#   'b1004',
#   'b1051',
#   'b1161',
#   'b1188',
#   'b1195',
#   'b1197',
#   'b1258',
#   'b1285',
#   'b1341',
#   'b1428',
#   'b1440',
#   'b1449',
#   'b1450',
#   'b1454',
#   'b1462',
#   'b1478',
#   'b1482',
#   'b1519',
#   'b1536',
#   'b1646',
#   'b1668',
#   'b1678',
#   'b1724',
#   'b1725',
#   'b1732',
#   'b1739',
#   'b1783',
#   'b1784',
#   'b1795',
#   'b1836',
#   'b1847',
#   'b1896',
#   'b1897',
#   'b1927',
#   'b1953',
#   'b1955',
#   'b2080',
#   'b2086',
#   'b2097',
#   'b2112',
#   'b2127',
#   'b2128',
#   'b2129',
#   'b2130',
#   'b2131',
#   'b2137',
#   'b2266',
#   'b2302',
#   'b2347',
#   'b2464',
#   'b2465',
#   'b2535',
#   'b2543',
#   'b2602',
#   'b2659',
#   'b2660',
#   'b2661',
#   'b2662',
#   'b2663',
#   'b2665',
#   'b2672',
#   'b2809',
#   'b3003',
#   'b3024',
#   'b3073',
#   'b3097',
#   'b3098',
#   'b3099',
#   'b3100',
#   'b3102',
#   'b3153',
#   'b3239',
#   'b3336',
#   'b3361',
#   'b3447',
#   'b3524',
#   'b3548',
#   'b3555',
#   'b3588',
#   'b4039',
#   'b4045',
#   'b4107',
#   'b4149',
#   'b4269',
#   'b4336',
#   'b4376',
#   'b4411',
#   'b4568'],
#  ['b0096',
#   'b0389',
#   'b0447',
#   'b0448',
#   'b0449',
#   'b0628',
#   'b0684',
#   'b0850',
#   'b0851',
#   'b0852',
#   'b0871',
#   'b1053',
#   'b1165',
#   'b1166',
#   'b1277',
#   'b1378',
#   'b1463',
#   'b1580',
#   'b1581',
#   'b1611',
#   'b1852',
#   'b2048',
#   'b2159',
#   'b2160',
#   'b2237',
#   'b2468',
#   'b2895',
#   'b2898',
#   'b2962',
#   'b2963',
#   'b3238',
#   'b3519',
#   'b3662',
#   'b3898',
#   'b3908',
#   'b3924',
#   'b3961',
#   'b4062',
#   'b4379',
#   'b4380',
#   'b4536'],
#  ['b2702', 'b2703', 'b2704', 'b2705', 'b2706'],
#  ['b0066',
#   'b0067',
#   'b0068',
#   'b2103',
#   'b2104',
#   'b3990',
#   'b3991',
#   'b3992',
#   'b3993',
#   'b3994',
#   'b4407'],
#  ['b1260',
#   'b1261',
#   'b1262',
#   'b1263',
#   'b1264',
#   'b1704',
#   'b2600',
#   'b2601',
#   'b3161',
#   'b3708',
#   'b3709'],
#  ['b0270',
#   'b0271',
#   'b3562',
#   'b3563',
#   'b3564',
#   'b3565',
#   'b3566',
#   'b3567',
#   'b3568',
#   'b3569',
#   'b3656',
#   'b3657',
#   'b4031'],
#  ['b0062',
#   'b0509',
#   'b1800',
#   'b2736',
#   'b2737',
#   'b2738',
#   'b2739',
#   'b2740',
#   'b2843'],
#  ['b3574',
#   'b3575',
#   'b3576',
#   'b3577',
#   'b3578',
#   'b3579',
#   'b3580',
#   'b3581',
#   'b3582',
#   'b3583'],
#  ['b0306',
#   'b0307',
#   'b0308',
#   'b0447',
#   'b1826',
#   'b2141',
#   'b2142',
#   'b2143',
#   'b3755',
#   'b4116',
#   'b4354'],
#  ['b0593', 'b1523', 'b1524', 'b1525', 'b1831'],
#  ['b0123',
#   'b0296',
#   'b0484',
#   'b1178',
#   'b1856',
#   'b1857',
#   'b1858',
#   'b1859',
#   'b1973',
#   'b1974',
#   'b3469',
#   'b4506'],
#  ['b0124',
#   'b0411',
#   'b0802',
#   'b1112',
#   'b1520',
#   'b1528',
#   'b1963',
#   'b2924',
#   'b3357',
#   'b3364',
#   'b3403',
#   'b4030',
#   'b4060',
#   'b4111'],
#  ['b1037', 'b1038', 'b1039', 'b1040'],
#  ['b0508',
#   'b1597',
#   'b1822',
#   'b1823',
#   'b1824',
#   'b1825',
#   'b1826',
#   'b1827',
#   'b1829',
#   'b1830',
#   'b1831',
#   'b1832',
#   'b1833',
#   'b1834',
#   'b1835',
#   'b1836',
#   'b1837',
#   'b1838',
#   'b1839',
#   'b1840',
#   'b1841',
#   'b1842',
#   'b1843',
#   'b1844',
#   'b1845',
#   'b1846',
#   'b1847',
#   'b1848',
#   'b1849',
#   'b1850',
#   'b1851',
#   'b1852',
#   'b1853',
#   'b1854',
#   'b1855',
#   'b1856',
#   'b2842',
#   'b2843',
#   'b3526',
#   'b3909',
#   'b4536'],
#  ['b0355',
#   'b0356',
#   'b0357',
#   'b1339',
#   'b1340',
#   'b1341',
#   'b1342',
#   'b1343',
#   'b1344',
#   'b1345',
#   'b1349',
#   'b1356',
#   'b1357',
#   'b1359',
#   'b1361',
#   'b1363',
#   'b1376',
#   'b1377',
#   'b1378',
#   'b1379',
#   'b1381',
#   'b1384',
#   'b1385',
#   'b1386',
#   'b1395',
#   'b1397',
#   'b1398',
#   'b1399',
#   'b1400',
#   'b1406',
#   'b1407',
#   'b1410',
#   'b1411',
#   'b1412',
#   'b1413',
#   'b1414',
#   'b1415',
#   'b1418',
#   'b1419',
#   'b1423',
#   'b1424',
#   'b1426',
#   'b1427',
#   'b1428',
#   'b1429',
#   'b1430',
#   'b1431',
#   'b1432',
#   'b1433',
#   'b1434',
#   'b1435',
#   'b1438',
#   'b1439',
#   'b1440',
#   'b1441',
#   'b1442',
#   'b1443',
#   'b1444',
#   'b1446',
#   'b1447',
#   'b1448',
#   'b1449',
#   'b1450',
#   'b1451',
#   'b1452',
#   'b1454',
#   'b1459_1',
#   'b1461',
#   'b1462',
#   'b1463',
#   'b1464',
#   'b1465',
#   'b1466',
#   'b1467',
#   'b1468',
#   'b1473',
#   'b1474',
#   'b1476',
#   'b1477',
#   'b1478',
#   'b1479',
#   'b1480',
#   'b1482',
#   'b1483',
#   'b1484',
#   'b1485',
#   'b1486',
#   'b1487',
#   'b1488',
#   'b1489',
#   'b1490',
#   'b1491',
#   'b1494',
#   'b1495',
#   'b1496',
#   'b1498',
#   'b1937',
#   'b1949',
#   'b3011',
#   'b3751',
#   'b3752',
#   'b4381',
#   'b4382',
#   'b4428',
#   'b4492_1',
#   'b4492_3',
#   'b4493_1',
#   'b4493_2',
#   'b4529',
#   'b4555'],
#  ['b0251',
#   'b0268',
#   'b0756',
#   'b0757',
#   'b0758',
#   'b0759',
#   'b1112',
#   'b1259',
#   'b1566',
#   'b2207',
#   'b2626',
#   'b2837',
#   'b2943',
#   'b3043',
#   'b3369',
#   'b3551',
#   'b3552',
#   'b3553',
#   'b3558',
#   'b3559',
#   'b3560',
#   'b3561',
#   'b3570',
#   'b3573',
#   'b3574',
#   'b3585',
#   'b3590',
#   'b3591',
#   'b3595',
#   'b3598',
#   'b3602',
#   'b3606',
#   'b3607',
#   'b3608',
#   'b3609',
#   'b3610',
#   'b3611',
#   'b3612',
#   'b3613',
#   'b3614',
#   'b3616',
#   'b3617',
#   'b3618',
#   'b3619',
#   'b3620',
#   'b3621',
#   'b3623',
#   'b3624',
#   'b3625',
#   'b3626',
#   'b3627',
#   'b3628',
#   'b3630',
#   'b3631',
#   'b3632',
#   'b3633',
#   'b3634',
#   'b3636',
#   'b3637',
#   'b3638',
#   'b3639',
#   'b3640',
#   'b3641',
#   'b3643_1',
#   'b3644',
#   'b3645',
#   'b3647',
#   'b3649',
#   'b3650',
#   'b3651',
#   'b3652',
#   'b3653',
#   'b3654',
#   'b3655',
#   'b3656',
#   'b3659',
#   'b3660',
#   'b3661',
#   'b3662',
#   'b3663',
#   'b4116',
#   'b4519',
#   'b4554',
#   'b4555'],
#  ['b1137',
#   'b1138',
#   'b1139',
#   'b1140',
#   'b1143',
#   'b1145',
#   'b1159',
#   'b1596',
#   'b3357',
#   'b4519',
#   'b4693'],
#  ['b0594', 'b0595', 'b0596', 'b0597', 'b1018', 'b1019', 'b2265', 'b4490_2'],
#  ['b0593', 'b2264', 'b2265'],
#  ['b0002', 'b4314', 'b4315', 'b4316', 'b4317', 'b4318', 'b4319', 'b4320'],
#  ['b0002', 'b0593', 'b0683', 'b2000', 'b2001', 'b2002', 'b2265', 'b4388'],
#  ['b0683',
#   'b0958',
#   'b1141',
#   'b1144',
#   'b1147',
#   'b1596',
#   'b1848',
#   'b2616',
#   'b2681_1',
#   'b3161',
#   'b4519',
#   'b4567',
#   'b4693'],
#  ['b3515', 'b3516'],
#  ['b1402',
#   'b1403',
#   'b1996',
#   'b1997',
#   'b2562',
#   'b2666',
#   'b2860',
#   'b2861',
#   'b4634'],
#  ['b1612',
#   'b1656',
#   'b2282',
#   'b2392',
#   'b2522',
#   'b2523',
#   'b2524',
#   'b2525',
#   'b2526',
#   'b2527',
#   'b2528',
#   'b2529',
#   'b2530',
#   'b3540',
#   'b3541',
#   'b3542',
#   'b3543',
#   'b4506',
#   'b4567',
#   'b4640_1'],
#  ['b0546',
#   'b0564',
#   'b1137',
#   'b1139',
#   'b1363',
#   'b1457',
#   'b1549',
#   'b1550',
#   'b2032',
#   'b2034',
#   'b2035',
#   'b2036',
#   'b2037',
#   'b2352',
#   'b2642',
#   'b2728',
#   'b2846',
#   'b3423_1',
#   'b3512',
#   'b3594',
#   'b3618',
#   'b3622',
#   'b3623',
#   'b3624',
#   'b3625',
#   'b3626',
#   'b3627',
#   'b3629',
#   'b4038_3',
#   'b4253',
#   'b4279',
#   'b4345',
#   'b4346',
#   'b4571_1',
#   'b4571_2',
#   'b4659_2'],
#  ['b1495',
#   'b1675',
#   'b1761',
#   'b2012',
#   'b2013',
#   'b2369',
#   'b2370',
#   'b2681_1',
#   'b2969',
#   'b2970',
#   'b2971',
#   'b2972',
#   'b3151',
#   'b4331',
#   'b4466'],
#  ['b0872',
#   'b0873',
#   'b1224',
#   'b1225',
#   'b1226',
#   'b1474',
#   'b1475',
#   'b1476',
#   'b1796',
#   'b1797',
#   'b2552',
#   'b2732',
#   'b3471',
#   'b4209'],
#  ['b0698', 'b2677', 'b2678', 'b2679'],
#  ['b1623', 'b1658', 'b3642'],
#  ['b4025', 'b4410', 'b4662', 'b4676'],
#  ['b0002', 'b0557', 'b2289'],
#  ['b0429',
#   'b0430',
#   'b2762',
#   'b3231',
#   'b3300',
#   'b3303',
#   'b3304',
#   'b3306',
#   'b3311',
#   'b3312',
#   'b3313',
#   'b3314',
#   'b3315',
#   'b3316',
#   'b3317',
#   'b3318',
#   'b3319',
#   'b3320',
#   'b3321',
#   'b3984',
#   'b4002',
#   'b4201',
#   'b4202',
#   'b4203'],
#  ['b0220',
#   'b0379',
#   'b0439',
#   'b1110',
#   'b1171',
#   'b1172',
#   'b1283',
#   'b1379',
#   'b1481',
#   'b1639',
#   'b1951',
#   'b2390',
#   'b2466',
#   'b2671',
#   'b4593'],
#  ['b0080',
#   'b0146',
#   'b0156',
#   'b0499',
#   'b0772',
#   'b0856',
#   'b0928',
#   'b1256',
#   'b1380',
#   'b1541',
#   'b1599',
#   'b1604',
#   'b1780',
#   'b1824',
#   'b1957',
#   'b1991',
#   'b1992',
#   'b2035',
#   'b2113',
#   'b2263',
#   'b2279',
#   'b2280',
#   'b2388',
#   'b2586',
#   'b2714',
#   'b2742',
#   'b2749',
#   'b2777',
#   'b2950',
#   'b2958',
#   'b3460',
#   'b3463',
#   'b3535',
#   'b3564',
#   'b3584',
#   'b3703',
#   'b3744',
#   'b3748',
#   'b4064',
#   'b4178',
#   'b4377',
#   'b4378'],
#  ['b2378', 'b3556'],
#  ['b0528',
#   'b0762',
#   'b1887',
#   'b2092_2',
#   'b2145',
#   'b2343',
#   'b3042',
#   'b3065',
#   'b3100',
#   'b4428'],
#  ['b2533', 'b3643_1', 'b3704', 'b4557'],
#  ['b0287',
#   'b0293',
#   'b0315',
#   'b0329',
#   'b0382',
#   'b0392',
#   'b0546',
#   'b0557',
#   'b0559',
#   'b0562_2',
#   'b0565',
#   'b0812',
#   'b0841',
#   'b0842',
#   'b0847',
#   'b0900',
#   'b0946',
#   'b1056',
#   'b1141',
#   'b1163',
#   'b1171',
#   'b1216',
#   'b1431',
#   'b1461',
#   'b1619',
#   'b1902',
#   'b1905',
#   'b1915',
#   'b1967',
#   'b1969',
#   'b2175',
#   'b2471',
#   'b2603',
#   'b2669',
#   'b2677',
#   'b2753',
#   'b2756',
#   'b3225',
#   'b3267',
#   'b3506',
#   'b3511',
#   'b3515',
#   'b3520',
#   'b3535',
#   'b3661',
#   'b3665',
#   'b3680',
#   'b3717',
#   'b3922',
#   'b3923',
#   'b4133',
#   'b4313',
#   'b4342',
#   'b4640_1'],
#  ['b0382', 'b1422', 'b4077'],
#  ['b0208',
#   'b0447',
#   'b1379',
#   'b1380',
#   'b1420',
#   'b1925',
#   'b2210',
#   'b3343',
#   'b3344',
#   'b3345',
#   'b3346',
#   'b3369',
#   'b3708',
#   'b4026',
#   'b4050',
#   'b4501']]

# %%
modules_as_sets = [set(module) for module in locus_tags]
modules_as_sets
# Out:
# [{'b0061',
#   'b0062',
#   'b0063',
#   'b0505',
#   'b0507',
#   'b0508',
#   'b0509',
#   'b0511',
#   'b0512',
#   'b1900',
#   'b1901',
#   'b2799',
#   'b2800',
#   'b2801',
#   'b2802',
#   'b2803',
#   'b2841',
#   'b4460'},
#  {'b0042',
#   'b0113',
#   'b0124',
#   'b0330',
#   'b0346',
#   'b0429',
#   'b0430',
#   'b0431',
#   'b0432',
#   'b0458',
#   'b0557',
#   'b0621',
#   'b0721',
#   'b0722',
#   'b0723',
#   'b0724',
#   'b0836',
#   'b0848',
#   'b1020',
#   'b1189',
#   'b1190',
#   'b1297',
#   'b1298',
#   'b1332',
#   'b1422',
#   'b1518',
#   'b1607',
#   'b1748',
#   'b1777',
#   'b1778',
#   'b2181',
#   'b2210',
#   'b2241',
#   'b2242',
#   'b2518',
#   'b2582',
#   'b2587',
#   'b2847',
#   'b2848',
#   'b2980',
#   'b3351',
#   'b3426',
#   'b3452',
#   'b3453',
#   'b3528',
#   'b3603',
#   'b3820',
#   'b3894',
#   'b3962',
#   'b4705'},
#  {'b0034',
#   'b0429',
#   'b0430',
#   'b0431',
#   'b0432',
#   'b0733',
#   'b0734',
#   'b0763',
#   'b0972',
#   'b0973',
#   'b0974',
#   'b0975',
#   'b0976',
#   'b0977',
#   'b0978',
#   'b0979',
#   'b1109',
#   'b1256',
#   'b2579',
#   'b2720',
#   'b2725',
#   'b2998',
#   'b4070',
#   'b4071',
#   'b4073'},
#  {'b0032',
#   'b0272',
#   'b0273',
#   'b0709',
#   'b0860',
#   'b2818',
#   'b3172',
#   'b3359',
#   'b3957',
#   'b3958',
#   'b3959',
#   'b3960',
#   'b4254'},
#  {'b1796', 'b1800', 'b2221', 'b2222', 'b2223', 'b2224'},
#  {'b0061',
#   'b0062',
#   'b0063',
#   'b0344',
#   'b0349',
#   'b0350',
#   'b0351',
#   'b0352',
#   'b0954',
#   'b2323',
#   'b2599',
#   'b2899',
#   'b3903',
#   'b4252',
#   'b4253',
#   'b4350',
#   'b4363'},
#  {'b0365',
#   'b0366',
#   'b0367',
#   'b0368',
#   'b0934',
#   'b0935',
#   'b0936',
#   'b0937',
#   'b3917',
#   'b4326'},
#  {'b0162',
#   'b1800',
#   'b2787',
#   'b2788',
#   'b2789',
#   'b3124',
#   'b3125',
#   'b3126',
#   'b3127',
#   'b3128'},
#  {'b0792', 'b0793', 'b0794', 'b0795', 'b0796'},
#  {'b0123', 'b0484', 'b0570', 'b0571', 'b0572', 'b0573', 'b0574', 'b0575'},
#  {'b0287',
#   'b0460',
#   'b0461',
#   'b0837',
#   'b0970',
#   'b1113',
#   'b1535',
#   'b1597',
#   'b1600',
#   'b1829',
#   'b1843',
#   'b1846',
#   'b1902',
#   'b2597',
#   'b3088',
#   'b4188',
#   'b4484'},
#  {'b0080',
#   'b1241',
#   'b1702',
#   'b1780',
#   'b2165',
#   'b2166',
#   'b2167',
#   'b2168',
#   'b2169',
#   'b2925',
#   'b2926',
#   'b2927',
#   'b3365',
#   'b3612',
#   'b4232'},
#  {'b0080',
#   'b0268',
#   'b0269',
#   'b0306',
#   'b0553_1',
#   'b0598',
#   'b0651',
#   'b0721',
#   'b0729',
#   'b0791',
#   'b0836',
#   'b0899',
#   'b1008',
#   'b1020',
#   'b1415',
#   'b1423',
#   'b1440',
#   'b1441',
#   'b1442',
#   'b1617',
#   'b1776',
#   'b1853',
#   'b1895',
#   'b1976',
#   'b2151',
#   'b2166',
#   'b2175',
#   'b2272',
#   'b2535',
#   'b2844',
#   'b2869',
#   'b2957',
#   'b3020',
#   'b3081',
#   'b3092',
#   'b3132',
#   'b3133',
#   'b3134',
#   'b3224',
#   'b3225',
#   'b3570',
#   'b3588',
#   'b3599',
#   'b3600',
#   'b3601',
#   'b3708',
#   'b3709',
#   'b3748',
#   'b3934',
#   'b4055',
#   'b4067',
#   'b4068',
#   'b4069',
#   'b4090',
#   'b4123',
#   'b4128',
#   'b4139',
#   'b4216',
#   'b4240',
#   'b4487'},
#  {'b0553_1',
#   'b0723',
#   'b1101',
#   'b1143',
#   'b1145',
#   'b1205',
#   'b1415',
#   'b1426',
#   'b1596',
#   'b1817',
#   'b1818',
#   'b1819',
#   'b2091',
#   'b2092_1',
#   'b2092_2',
#   'b2093',
#   'b2094',
#   'b2095',
#   'b2096',
#   'b2143',
#   'b2148',
#   'b2149',
#   'b2150',
#   'b2151',
#   'b2239',
#   'b2240',
#   'b2597',
#   'b2796',
#   'b3001',
#   'b3358',
#   'b3403',
#   'b3476',
#   'b3599',
#   'b3600',
#   'b3601',
#   'b3774',
#   'b4021',
#   'b4267',
#   'b4357',
#   'b4498_1'},
#  {'b3875',
#   'b3876',
#   'b3877',
#   'b3878',
#   'b3879',
#   'b3880',
#   'b3881',
#   'b3882',
#   'b3883',
#   'b3884'},
#  {'b0828',
#   'b0829',
#   'b1287',
#   'b1729',
#   'b1920',
#   'b1987',
#   'b2012',
#   'b2013',
#   'b2414',
#   'b2421',
#   'b2422',
#   'b2423',
#   'b2424',
#   'b2425',
#   'b2750',
#   'b2751',
#   'b2752',
#   'b2762',
#   'b2763',
#   'b2764',
#   'b3917'},
#  {'b1101',
#   'b1198',
#   'b1199',
#   'b1200',
#   'b1817',
#   'b1818',
#   'b1819',
#   'b2416',
#   'b2943',
#   'b3599',
#   'b3600'},
#  {'b1223',
#   'b1466',
#   'b1467',
#   'b1468',
#   'b1469',
#   'b1499',
#   'b1501',
#   'b1597',
#   'b2082',
#   'b2085',
#   'b2106',
#   'b2367',
#   'b2368',
#   'b2371',
#   'b2372',
#   'b2373',
#   'b2374',
#   'b2375',
#   'b2376',
#   'b4354'},
#  {'b0268',
#   'b0269',
#   'b1521',
#   'b2172',
#   'b2799',
#   'b2800',
#   'b2801',
#   'b2802',
#   'b2803',
#   'b2804',
#   'b3011',
#   'b3091',
#   'b3092',
#   'b3093',
#   'b4025'},
#  {'b0221',
#   'b0443',
#   'b0557',
#   'b0954',
#   'b1187',
#   'b1949',
#   'b2341',
#   'b2342',
#   'b3081',
#   'b3845',
#   'b3846',
#   'b3963',
#   'b4015'},
#  {'b0595',
#   'b1018',
#   'b1019',
#   'b4039',
#   'b4287',
#   'b4288',
#   'b4289',
#   'b4290',
#   'b4291',
#   'b4490_2'},
#  {'b1044',
#   'b1070',
#   'b1071',
#   'b1072',
#   'b1073',
#   'b1074',
#   'b1075',
#   'b1076',
#   'b1077',
#   'b1078',
#   'b1079',
#   'b1080',
#   'b1081',
#   'b1082',
#   'b1083',
#   'b1878',
#   'b1879',
#   'b1880',
#   'b1891',
#   'b1892',
#   'b1904',
#   'b1921',
#   'b1922',
#   'b1924',
#   'b1925',
#   'b1926',
#   'b1937',
#   'b1938',
#   'b1939',
#   'b1940',
#   'b1941',
#   'b1942',
#   'b1943',
#   'b1944',
#   'b1945',
#   'b1946',
#   'b1947',
#   'b1948',
#   'b1949',
#   'b1950',
#   'b3525'},
#  {'b0763',
#   'b0764',
#   'b1070',
#   'b1071',
#   'b1082',
#   'b1083',
#   'b1194',
#   'b1421',
#   'b1566',
#   'b1742',
#   'b1760',
#   'b1881',
#   'b1882',
#   'b1883',
#   'b1884',
#   'b1885',
#   'b1886',
#   'b1887',
#   'b1888',
#   'b1889',
#   'b1890',
#   'b1923',
#   'b1924',
#   'b1925',
#   'b1926',
#   'b3072',
#   'b3525',
#   'b3666',
#   'b4110',
#   'b4355'},
#  {'b0621',
#   'b0715',
#   'b0836',
#   'b0894',
#   'b0904',
#   'b0919',
#   'b1223',
#   'b1224',
#   'b1256',
#   'b1474',
#   'b1541',
#   'b1587',
#   'b1593',
#   'b1750',
#   'b1751',
#   'b1757',
#   'b1785',
#   'b1906',
#   'b2207',
#   'b2208',
#   'b2298',
#   'b2531',
#   'b2579',
#   'b2727',
#   'b2997',
#   'b3060',
#   'b3158',
#   'b3159',
#   'b3211',
#   'b3365',
#   'b3366',
#   'b3408',
#   'b3409',
#   'b3476',
#   'b3477',
#   'b4139',
#   'b4154',
#   'b4238',
#   'b4380',
#   'b4582_1'},
#  {'b0151',
#   'b0152',
#   'b0153',
#   'b0583',
#   'b0584',
#   'b0585',
#   'b0586',
#   'b0587',
#   'b0588',
#   'b0589',
#   'b0590',
#   'b0591',
#   'b0592',
#   'b0593',
#   'b0594',
#   'b0595',
#   'b0596',
#   'b0597',
#   'b0803',
#   'b0804',
#   'b0805',
#   'b1102',
#   'b1452',
#   'b1494',
#   'b1495',
#   'b1496',
#   'b1656',
#   'b1679',
#   'b1680',
#   'b1681',
#   'b1682',
#   'b1683',
#   'b1684',
#   'b1705',
#   'b2155',
#   'b2673',
#   'b2674',
#   'b2675',
#   'b2676',
#   'b3070',
#   'b3336',
#   'b4291',
#   'b4292',
#   'b4293',
#   'b4511',
#   'b4567',
#   'b4582_1',
#   'b4640_1'},
#  {'b0150',
#   'b0151',
#   'b0152',
#   'b0468',
#   'b0585',
#   'b0588',
#   'b0589',
#   'b0590',
#   'b0591',
#   'b0592',
#   'b1252',
#   'b1452',
#   'b1673',
#   'b1674',
#   'b1905',
#   'b2146',
#   'b2211',
#   'b2673',
#   'b3005',
#   'b3006',
#   'b3337',
#   'b3408',
#   'b3409',
#   'b3515',
#   'b4293',
#   'b4367',
#   'b4490_2'},
#  {'b0485',
#   'b1492',
#   'b1493',
#   'b3491',
#   'b3506',
#   'b3507',
#   'b3508',
#   'b3509',
#   'b3510',
#   'b3511',
#   'b3512',
#   'b3513',
#   'b3514',
#   'b3515',
#   'b3517',
#   'b4187',
#   'b4377'},
#  {'b0485', 'b0486', 'b3506', 'b3507', 'b3513', 'b3514', 'b3515', 'b3516'},
#  {'b2902', 'b2903', 'b2904', 'b2905'},
#  {'b2975', 'b2976', 'b2977', 'b2979', 'b4467', 'b4468'},
#  {'b2239',
#   'b2240',
#   'b2241',
#   'b2242',
#   'b2243',
#   'b3426',
#   'b3925',
#   'b3926',
#   'b3927'},
#  {'b0112',
#   'b1850',
#   'b1851',
#   'b1907',
#   'b3161',
#   'b3415',
#   'b3437',
#   'b3892',
#   'b3893',
#   'b4264',
#   'b4265',
#   'b4266',
#   'b4267',
#   'b4268',
#   'b4476'},
#  {'b2019',
#   'b2020',
#   'b2021',
#   'b2022',
#   'b2023',
#   'b2024',
#   'b2025',
#   'b2026',
#   'b4388'},
#  {'b0003',
#   'b0004',
#   'b0005',
#   'b0071',
#   'b0072',
#   'b0073',
#   'b0074',
#   'b3769',
#   'b3770',
#   'b3771',
#   'b3772',
#   'b3774',
#   'b4488_1',
#   'b4488_2'},
#  {'b0077',
#   'b0078',
#   'b0381',
#   'b1189',
#   'b1190',
#   'b1243',
#   'b1244',
#   'b1245',
#   'b1246',
#   'b1247',
#   'b1534',
#   'b1605',
#   'b1634',
#   'b1798',
#   'b1814',
#   'b2209',
#   'b2669',
#   'b2670',
#   'b2796',
#   'b2797',
#   'b2845',
#   'b3089',
#   'b3454',
#   'b3455',
#   'b3456',
#   'b3457',
#   'b3458',
#   'b3460',
#   'b3496',
#   'b3523',
#   'b3616',
#   'b3617',
#   'b3673',
#   'b3774',
#   'b3829',
#   'b4045',
#   'b4129'},
#  {'b3416',
#   'b3417',
#   'b3418',
#   'b4032',
#   'b4033',
#   'b4034',
#   'b4035',
#   'b4036',
#   'b4037'},
#  {'b0197',
#   'b0198',
#   'b0199',
#   'b0260',
#   'b0261',
#   'b0599',
#   'b0600',
#   'b2942',
#   'b3008',
#   'b3828',
#   'b3829',
#   'b3937',
#   'b3938',
#   'b3939',
#   'b3940',
#   'b3941',
#   'b4013'},
#  {'b0336',
#   'b0338',
#   'b0644',
#   'b0929',
#   'b1339',
#   'b1384',
#   'b1440',
#   'b1441',
#   'b1442',
#   'b1443',
#   'b1444',
#   'b1932',
#   'b1981',
#   'b1988',
#   'b2661',
#   'b2662',
#   'b2663',
#   'b2664',
#   'b2883',
#   'b2913',
#   'b3043',
#   'b3212',
#   'b3213',
#   'b3225',
#   'b3324',
#   'b3326',
#   'b3446',
#   'b3523',
#   'b3540',
#   'b3541',
#   'b3543',
#   'b3544',
#   'b3712',
#   'b3744',
#   'b4208',
#   'b4464',
#   'b4646_2'},
#  {'b0112',
#   'b0677',
#   'b0678',
#   'b0679',
#   'b0681',
#   'b1497',
#   'b1498',
#   'b1634',
#   'b1734',
#   'b1735',
#   'b1737',
#   'b1738',
#   'b1907',
#   'b2943',
#   'b3161',
#   'b3729',
#   'b3730'},
#  {'b0895',
#   'b0896',
#   'b1223',
#   'b1224',
#   'b1225',
#   'b1226',
#   'b1227',
#   'b2111',
#   'b2195',
#   'b2196',
#   'b2197',
#   'b2199',
#   'b2201',
#   'b2202',
#   'b2203',
#   'b2204',
#   'b2205',
#   'b2206',
#   'b2207',
#   'b2208',
#   'b3365',
#   'b3366',
#   'b3367',
#   'b3476',
#   'b4070',
#   'b4071',
#   'b4072',
#   'b4073',
#   'b4506'},
#  {'b0208', 'b3476', 'b3477', 'b3478', 'b3479', 'b3480'},
#  {'b0331',
#   'b0450',
#   'b0451',
#   'b0655',
#   'b0674',
#   'b0854',
#   'b1006',
#   'b1007',
#   'b1008',
#   'b1009',
#   'b1010',
#   'b1011',
#   'b1012',
#   'b1218',
#   'b1483',
#   'b1484',
#   'b1485',
#   'b1486',
#   'b1487',
#   'b1488',
#   'b1596',
#   'b1597',
#   'b1744',
#   'b1745',
#   'b1746',
#   'b1747',
#   'b1748',
#   'b1781',
#   'b1783',
#   'b1784',
#   'b1797',
#   'b1826',
#   'b1932',
#   'b1987',
#   'b2106',
#   'b2306',
#   'b2310',
#   'b2659',
#   'b2660',
#   'b2663',
#   'b2726',
#   'b2870',
#   'b2875',
#   'b2876',
#   'b3073',
#   'b3268_2',
#   'b3269',
#   'b3270',
#   'b3271',
#   'b3744',
#   'b3868',
#   'b3869',
#   'b3870',
#   'b4002',
#   'b4079',
#   'b4242'},
#  {'b0605', 'b0606', 'b0812', 'b0849', 'b2582', 'b3518', 'b3942', 'b3961'},
#  {'b0331', 'b0333', 'b0334', 'b0335', 'b2416', 'b2943'},
#  {'b0522',
#   'b0523',
#   'b1131',
#   'b1623',
#   'b1660',
#   'b1849',
#   'b2312',
#   'b2313',
#   'b2476',
#   'b2499',
#   'b2500',
#   'b2557',
#   'b3654',
#   'b4005',
#   'b4006',
#   'b4064'},
#  {'b0032',
#   'b0033',
#   'b0336',
#   'b0337',
#   'b0945',
#   'b2497',
#   'b2498',
#   'b4243',
#   'b4244',
#   'b4245'},
#  {'b1296', 'b1297', 'b1298', 'b1299', 'b1300', 'b1301', 'b1302'},
#  {'b0114', 'b0115', 'b1380', 'b2210', 'b2296', 'b3547', 'b4353', 'b4354'},
#  {'b3666', 'b3748', 'b3749', 'b3750', 'b3751', 'b3752'},
#  {'b0439',
#   'b1951',
#   'b2028',
#   'b2044',
#   'b2045',
#   'b2046',
#   'b2047',
#   'b2048',
#   'b2049',
#   'b2050',
#   'b2051',
#   'b2052',
#   'b2053',
#   'b2054',
#   'b2055',
#   'b2056',
#   'b2057',
#   'b2058',
#   'b2059',
#   'b2060',
#   'b2061',
#   'b2062',
#   'b3357',
#   'b3563',
#   'b4026',
#   'b4027',
#   'b4028',
#   'b4029'},
#  {'b0014',
#   'b0015',
#   'b0473',
#   'b1321',
#   'b1322',
#   'b2592',
#   'b3686',
#   'b3687',
#   'b3931',
#   'b3932',
#   'b4140',
#   'b4142',
#   'b4143'},
#  {'b0304',
#   'b0325',
#   'b0329',
#   'b0384',
#   'b0453',
#   'b0456',
#   'b0581',
#   'b0643',
#   'b0707',
#   'b0753',
#   'b0788',
#   'b0789',
#   'b0790',
#   'b0808',
#   'b0837',
#   'b0871',
#   'b0897',
#   'b0906',
#   'b1003',
#   'b1004',
#   'b1051',
#   'b1161',
#   'b1188',
#   'b1195',
#   'b1197',
#   'b1258',
#   'b1285',
#   'b1341',
#   'b1428',
#   'b1440',
#   'b1449',
#   'b1450',
#   'b1454',
#   'b1462',
#   'b1478',
#   'b1482',
#   'b1519',
#   'b1536',
#   'b1646',
#   'b1668',
#   'b1678',
#   'b1724',
#   'b1725',
#   'b1732',
#   'b1739',
#   'b1783',
#   'b1784',
#   'b1795',
#   'b1836',
#   'b1847',
#   'b1896',
#   'b1897',
#   'b1927',
#   'b1953',
#   'b1955',
#   'b2080',
#   'b2086',
#   'b2097',
#   'b2112',
#   'b2127',
#   'b2128',
#   'b2129',
#   'b2130',
#   'b2131',
#   'b2137',
#   'b2266',
#   'b2302',
#   'b2347',
#   'b2464',
#   'b2465',
#   'b2535',
#   'b2543',
#   'b2602',
#   'b2659',
#   'b2660',
#   'b2661',
#   'b2662',
#   'b2663',
#   'b2665',
#   'b2672',
#   'b2809',
#   'b3003',
#   'b3024',
#   'b3073',
#   'b3097',
#   'b3098',
#   'b3099',
#   'b3100',
#   'b3102',
#   'b3153',
#   'b3239',
#   'b3336',
#   'b3361',
#   'b3447',
#   'b3524',
#   'b3548',
#   'b3555',
#   'b3588',
#   'b4039',
#   'b4045',
#   'b4107',
#   'b4149',
#   'b4269',
#   'b4336',
#   'b4376',
#   'b4411',
#   'b4568'},
#  {'b0096',
#   'b0389',
#   'b0447',
#   'b0448',
#   'b0449',
#   'b0628',
#   'b0684',
#   'b0850',
#   'b0851',
#   'b0852',
#   'b0871',
#   'b1053',
#   'b1165',
#   'b1166',
#   'b1277',
#   'b1378',
#   'b1463',
#   'b1580',
#   'b1581',
#   'b1611',
#   'b1852',
#   'b2048',
#   'b2159',
#   'b2160',
#   'b2237',
#   'b2468',
#   'b2895',
#   'b2898',
#   'b2962',
#   'b2963',
#   'b3238',
#   'b3519',
#   'b3662',
#   'b3898',
#   'b3908',
#   'b3924',
#   'b3961',
#   'b4062',
#   'b4379',
#   'b4380',
#   'b4536'},
#  {'b2702', 'b2703', 'b2704', 'b2705', 'b2706'},
#  {'b0066',
#   'b0067',
#   'b0068',
#   'b2103',
#   'b2104',
#   'b3990',
#   'b3991',
#   'b3992',
#   'b3993',
#   'b3994',
#   'b4407'},
#  {'b1260',
#   'b1261',
#   'b1262',
#   'b1263',
#   'b1264',
#   'b1704',
#   'b2600',
#   'b2601',
#   'b3161',
#   'b3708',
#   'b3709'},
#  {'b0270',
#   'b0271',
#   'b3562',
#   'b3563',
#   'b3564',
#   'b3565',
#   'b3566',
#   'b3567',
#   'b3568',
#   'b3569',
#   'b3656',
#   'b3657',
#   'b4031'},
#  {'b0062',
#   'b0509',
#   'b1800',
#   'b2736',
#   'b2737',
#   'b2738',
#   'b2739',
#   'b2740',
#   'b2843'},
#  {'b3574',
#   'b3575',
#   'b3576',
#   'b3577',
#   'b3578',
#   'b3579',
#   'b3580',
#   'b3581',
#   'b3582',
#   'b3583'},
#  {'b0306',
#   'b0307',
#   'b0308',
#   'b0447',
#   'b1826',
#   'b2141',
#   'b2142',
#   'b2143',
#   'b3755',
#   'b4116',
#   'b4354'},
#  {'b0593', 'b1523', 'b1524', 'b1525', 'b1831'},
#  {'b0123',
#   'b0296',
#   'b0484',
#   'b1178',
#   'b1856',
#   'b1857',
#   'b1858',
#   'b1859',
#   'b1973',
#   'b1974',
#   'b3469',
#   'b4506'},
#  {'b0124',
#   'b0411',
#   'b0802',
#   'b1112',
#   'b1520',
#   'b1528',
#   'b1963',
#   'b2924',
#   'b3357',
#   'b3364',
#   'b3403',
#   'b4030',
#   'b4060',
#   'b4111'},
#  {'b1037', 'b1038', 'b1039', 'b1040'},
#  {'b0508',
#   'b1597',
#   'b1822',
#   'b1823',
#   'b1824',
#   'b1825',
#   'b1826',
#   'b1827',
#   'b1829',
#   'b1830',
#   'b1831',
#   'b1832',
#   'b1833',
#   'b1834',
#   'b1835',
#   'b1836',
#   'b1837',
#   'b1838',
#   'b1839',
#   'b1840',
#   'b1841',
#   'b1842',
#   'b1843',
#   'b1844',
#   'b1845',
#   'b1846',
#   'b1847',
#   'b1848',
#   'b1849',
#   'b1850',
#   'b1851',
#   'b1852',
#   'b1853',
#   'b1854',
#   'b1855',
#   'b1856',
#   'b2842',
#   'b2843',
#   'b3526',
#   'b3909',
#   'b4536'},
#  {'b0355',
#   'b0356',
#   'b0357',
#   'b1339',
#   'b1340',
#   'b1341',
#   'b1342',
#   'b1343',
#   'b1344',
#   'b1345',
#   'b1349',
#   'b1356',
#   'b1357',
#   'b1359',
#   'b1361',
#   'b1363',
#   'b1376',
#   'b1377',
#   'b1378',
#   'b1379',
#   'b1381',
#   'b1384',
#   'b1385',
#   'b1386',
#   'b1395',
#   'b1397',
#   'b1398',
#   'b1399',
#   'b1400',
#   'b1406',
#   'b1407',
#   'b1410',
#   'b1411',
#   'b1412',
#   'b1413',
#   'b1414',
#   'b1415',
#   'b1418',
#   'b1419',
#   'b1423',
#   'b1424',
#   'b1426',
#   'b1427',
#   'b1428',
#   'b1429',
#   'b1430',
#   'b1431',
#   'b1432',
#   'b1433',
#   'b1434',
#   'b1435',
#   'b1438',
#   'b1439',
#   'b1440',
#   'b1441',
#   'b1442',
#   'b1443',
#   'b1444',
#   'b1446',
#   'b1447',
#   'b1448',
#   'b1449',
#   'b1450',
#   'b1451',
#   'b1452',
#   'b1454',
#   'b1459_1',
#   'b1461',
#   'b1462',
#   'b1463',
#   'b1464',
#   'b1465',
#   'b1466',
#   'b1467',
#   'b1468',
#   'b1473',
#   'b1474',
#   'b1476',
#   'b1477',
#   'b1478',
#   'b1479',
#   'b1480',
#   'b1482',
#   'b1483',
#   'b1484',
#   'b1485',
#   'b1486',
#   'b1487',
#   'b1488',
#   'b1489',
#   'b1490',
#   'b1491',
#   'b1494',
#   'b1495',
#   'b1496',
#   'b1498',
#   'b1937',
#   'b1949',
#   'b3011',
#   'b3751',
#   'b3752',
#   'b4381',
#   'b4382',
#   'b4428',
#   'b4492_1',
#   'b4492_3',
#   'b4493_1',
#   'b4493_2',
#   'b4529',
#   'b4555'},
#  {'b0251',
#   'b0268',
#   'b0756',
#   'b0757',
#   'b0758',
#   'b0759',
#   'b1112',
#   'b1259',
#   'b1566',
#   'b2207',
#   'b2626',
#   'b2837',
#   'b2943',
#   'b3043',
#   'b3369',
#   'b3551',
#   'b3552',
#   'b3553',
#   'b3558',
#   'b3559',
#   'b3560',
#   'b3561',
#   'b3570',
#   'b3573',
#   'b3574',
#   'b3585',
#   'b3590',
#   'b3591',
#   'b3595',
#   'b3598',
#   'b3602',
#   'b3606',
#   'b3607',
#   'b3608',
#   'b3609',
#   'b3610',
#   'b3611',
#   'b3612',
#   'b3613',
#   'b3614',
#   'b3616',
#   'b3617',
#   'b3618',
#   'b3619',
#   'b3620',
#   'b3621',
#   'b3623',
#   'b3624',
#   'b3625',
#   'b3626',
#   'b3627',
#   'b3628',
#   'b3630',
#   'b3631',
#   'b3632',
#   'b3633',
#   'b3634',
#   'b3636',
#   'b3637',
#   'b3638',
#   'b3639',
#   'b3640',
#   'b3641',
#   'b3643_1',
#   'b3644',
#   'b3645',
#   'b3647',
#   'b3649',
#   'b3650',
#   'b3651',
#   'b3652',
#   'b3653',
#   'b3654',
#   'b3655',
#   'b3656',
#   'b3659',
#   'b3660',
#   'b3661',
#   'b3662',
#   'b3663',
#   'b4116',
#   'b4519',
#   'b4554',
#   'b4555'},
#  {'b1137',
#   'b1138',
#   'b1139',
#   'b1140',
#   'b1143',
#   'b1145',
#   'b1159',
#   'b1596',
#   'b3357',
#   'b4519',
#   'b4693'},
#  {'b0594', 'b0595', 'b0596', 'b0597', 'b1018', 'b1019', 'b2265', 'b4490_2'},
#  {'b0593', 'b2264', 'b2265'},
#  {'b0002', 'b4314', 'b4315', 'b4316', 'b4317', 'b4318', 'b4319', 'b4320'},
#  {'b0002', 'b0593', 'b0683', 'b2000', 'b2001', 'b2002', 'b2265', 'b4388'},
#  {'b0683',
#   'b0958',
#   'b1141',
#   'b1144',
#   'b1147',
#   'b1596',
#   'b1848',
#   'b2616',
#   'b2681_1',
#   'b3161',
#   'b4519',
#   'b4567',
#   'b4693'},
#  {'b3515', 'b3516'},
#  {'b1402',
#   'b1403',
#   'b1996',
#   'b1997',
#   'b2562',
#   'b2666',
#   'b2860',
#   'b2861',
#   'b4634'},
#  {'b1612',
#   'b1656',
#   'b2282',
#   'b2392',
#   'b2522',
#   'b2523',
#   'b2524',
#   'b2525',
#   'b2526',
#   'b2527',
#   'b2528',
#   'b2529',
#   'b2530',
#   'b3540',
#   'b3541',
#   'b3542',
#   'b3543',
#   'b4506',
#   'b4567',
#   'b4640_1'},
#  {'b0546',
#   'b0564',
#   'b1137',
#   'b1139',
#   'b1363',
#   'b1457',
#   'b1549',
#   'b1550',
#   'b2032',
#   'b2034',
#   'b2035',
#   'b2036',
#   'b2037',
#   'b2352',
#   'b2642',
#   'b2728',
#   'b2846',
#   'b3423_1',
#   'b3512',
#   'b3594',
#   'b3618',
#   'b3622',
#   'b3623',
#   'b3624',
#   'b3625',
#   'b3626',
#   'b3627',
#   'b3629',
#   'b4038_3',
#   'b4253',
#   'b4279',
#   'b4345',
#   'b4346',
#   'b4571_1',
#   'b4571_2',
#   'b4659_2'},
#  {'b1495',
#   'b1675',
#   'b1761',
#   'b2012',
#   'b2013',
#   'b2369',
#   'b2370',
#   'b2681_1',
#   'b2969',
#   'b2970',
#   'b2971',
#   'b2972',
#   'b3151',
#   'b4331',
#   'b4466'},
#  {'b0872',
#   'b0873',
#   'b1224',
#   'b1225',
#   'b1226',
#   'b1474',
#   'b1475',
#   'b1476',
#   'b1796',
#   'b1797',
#   'b2552',
#   'b2732',
#   'b3471',
#   'b4209'},
#  {'b0698', 'b2677', 'b2678', 'b2679'},
#  {'b1623', 'b1658', 'b3642'},
#  {'b4025', 'b4410', 'b4662', 'b4676'},
#  {'b0002', 'b0557', 'b2289'},
#  {'b0429',
#   'b0430',
#   'b2762',
#   'b3231',
#   'b3300',
#   'b3303',
#   'b3304',
#   'b3306',
#   'b3311',
#   'b3312',
#   'b3313',
#   'b3314',
#   'b3315',
#   'b3316',
#   'b3317',
#   'b3318',
#   'b3319',
#   'b3320',
#   'b3321',
#   'b3984',
#   'b4002',
#   'b4201',
#   'b4202',
#   'b4203'},
#  {'b0220',
#   'b0379',
#   'b0439',
#   'b1110',
#   'b1171',
#   'b1172',
#   'b1283',
#   'b1379',
#   'b1481',
#   'b1639',
#   'b1951',
#   'b2390',
#   'b2466',
#   'b2671',
#   'b4593'},
#  {'b0080',
#   'b0146',
#   'b0156',
#   'b0499',
#   'b0772',
#   'b0856',
#   'b0928',
#   'b1256',
#   'b1380',
#   'b1541',
#   'b1599',
#   'b1604',
#   'b1780',
#   'b1824',
#   'b1957',
#   'b1991',
#   'b1992',
#   'b2035',
#   'b2113',
#   'b2263',
#   'b2279',
#   'b2280',
#   'b2388',
#   'b2586',
#   'b2714',
#   'b2742',
#   'b2749',
#   'b2777',
#   'b2950',
#   'b2958',
#   'b3460',
#   'b3463',
#   'b3535',
#   'b3564',
#   'b3584',
#   'b3703',
#   'b3744',
#   'b3748',
#   'b4064',
#   'b4178',
#   'b4377',
#   'b4378'},
#  {'b2378', 'b3556'},
#  {'b0528',
#   'b0762',
#   'b1887',
#   'b2092_2',
#   'b2145',
#   'b2343',
#   'b3042',
#   'b3065',
#   'b3100',
#   'b4428'},
#  {'b2533', 'b3643_1', 'b3704', 'b4557'},
#  {'b0287',
#   'b0293',
#   'b0315',
#   'b0329',
#   'b0382',
#   'b0392',
#   'b0546',
#   'b0557',
#   'b0559',
#   'b0562_2',
#   'b0565',
#   'b0812',
#   'b0841',
#   'b0842',
#   'b0847',
#   'b0900',
#   'b0946',
#   'b1056',
#   'b1141',
#   'b1163',
#   'b1171',
#   'b1216',
#   'b1431',
#   'b1461',
#   'b1619',
#   'b1902',
#   'b1905',
#   'b1915',
#   'b1967',
#   'b1969',
#   'b2175',
#   'b2471',
#   'b2603',
#   'b2669',
#   'b2677',
#   'b2753',
#   'b2756',
#   'b3225',
#   'b3267',
#   'b3506',
#   'b3511',
#   'b3515',
#   'b3520',
#   'b3535',
#   'b3661',
#   'b3665',
#   'b3680',
#   'b3717',
#   'b3922',
#   'b3923',
#   'b4133',
#   'b4313',
#   'b4342',
#   'b4640_1'},
#  {'b0382', 'b1422', 'b4077'},
#  {'b0208',
#   'b0447',
#   'b1379',
#   'b1380',
#   'b1420',
#   'b1925',
#   'b2210',
#   'b3343',
#   'b3344',
#   'b3345',
#   'b3346',
#   'b3369',
#   'b3708',
#   'b4026',
#   'b4050',
#   'b4501'}]

# %%
ModulesA = Modules(modules_as_sets)
ModulesB = Modules(known_modules)
Modules_genes = Modules(all_genes)
mod_comp = ModulesComparison(ModulesA, ModulesB, all_genes)

# %%
scores_list = []
scores = ModulesComparison(ModulesA, ModulesB, all_genes).score(None)
scores_list.append((scores['precision'], scores['recall'], scores['F1rp'], scores['recovery'], scores['relevance'], scores['F1rr'], scores['F1rprr']))
scores_method = pd.DataFrame(scores_list, columns=['precision', 'recall', 'f1rp', 'recovery', 'relevance', 'f1rr', 'f1rprr'])

# %%
scores_method
# Out:
#    precision    recall      f1rp  recovery  relevance      f1rr    f1rprr
# 0   0.012267  0.030796  0.017545  0.231147   0.227852  0.229488  0.032597

# %%
allgenes = sorted(list({g for module in known_modules for g in module}))

# %%
scores_list = []
scores = ModulesComparison(ModulesA, ModulesB, allgenes).score(None)
scores_list.append((scores['precision'], scores['recall'], scores['F1rp'], scores['recovery'], scores['relevance'], scores['F1rr'], scores['F1rprr']))
scores_method = pd.DataFrame(scores_list, columns=['precision', 'recall', 'f1rp', 'recovery', 'relevance', 'f1rr', 'f1rprr'])

# %%
scores_method
# Out:
#    precision    recall      f1rp  recovery  relevance      f1rr    f1rprr
# 0   0.030314  0.085846  0.044806  0.259555   0.248805  0.254066  0.076178
